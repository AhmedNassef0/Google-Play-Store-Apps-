# %% [markdown]
# <img src="https://www.opticflux.com/wp-content/uploads/2021/05/Google-Play-Store.jpg" alt="Google Play Store (Android TV) Version 25.1.24 Improves Its Features -  Optic Flux" jsname="HiaYvf" jsaction="load:XAeZkd;" class="n3VNCb" data-noaft="1" style="margin-left: 10%; float: center;  border:5px solid ; width:70%; height : 100%;">

# %% [markdown]
# * Today, 1.85 million different apps are available for users to download. Android users have even more from which to choose, with 2.56 million available through the Google Play Store. These apps have come to play a huge role in the way we live our lives today.

# %% [markdown]
# * This data scraped in 2018. So, the last updated year will be 2018.

# %%
#Importing needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Importing Data

# %%
apps=pd.read_csv('googleplaystore.csv')

# %%
apps.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
apps.shape
# Out:
# (10841, 13)

# %%
#Make columns names in lower case to be easy to write
apps.columns = [x.lower() for x in apps.columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Drop duplicates

# %%
apps[apps.duplicated()]
# Out:
#                                                    app      category  rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
apps.drop_duplicates(inplace=True)
apps[apps.duplicated()]
# Out:
# Empty DataFrame
# Columns: [app, category, rating, reviews, size, installs, type, price, content rating, genres, last updated, current ver, android ver]
# Index: []

# %%
apps.shape
# Out:
# (10358, 13)

# %% [markdown]
# #### Check if there are any duplicated apps

# %%
apps[apps.duplicated('app')]
# Out:
#                                             app       category  rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         reviews                size        installs  type price  \
# ...

# %% [markdown]
# ###### Let's drop them

# %%
#apps=apps.drop_duplicates(subset =["app"])

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10358 non-null  object
#  1   category        10358 non-null  object
#  2   rating          8893 non-null   float64
#  3   reviews         10358 non-null  object
#  4   size            10358 non-null  object
#  5   installs        10358 non-null  object
#  6   type            10357 non-null  object
#  7   price           10358 non-null  object
#  8   content rating  10357 non-null  object
#  9   genres          10358 non-null  object
#  10  last updated    10358 non-null  object
#  11  current ver     10350 non-null  object
#  12  android ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Clean Installs and Price

# %%
apps['installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
apps['price'].unique()
# Out:
# array(['0', '$4.99 ', '$3.99 ', '$6.99 ', '$1.49 ', '$2.99 ', '$7.99 ',
#        '$5.99 ', '$3.49 ', '$1.99 ', '$9.99 ', '$7.49 ', '$0.99 ',
#        '$9.00 ', '$5.49 ', '$10.00 ', '$24.99 ', '$11.99 ', '$79.99 ',
#        '$16.99 ', '$14.99 ', '$1.00 ', '$29.99 ', '$12.99 ', '$2.49 ',
#        '$10.99 ', '$1.50 ', '$19.99 ', '$15.99 ', '$33.99 ', '$74.99 ',
#        '$39.99 ', '$3.95 ', '$4.49 ', '$1.70 ', '$8.99 ', '$2.00 ',
#        '$3.88 ', '$25.99 ', '$399.99 ', '$17.99 ', '$400.00 ', '$3.02 ',
#        '$1.76 ', '$4.84 ', '$4.77 ', '$1.61 ', '$2.50 ', '$1.59 ',
#        '$6.49 ', '$1.29 ', '$5.00 ', '$13.99 ', '$299.99 ', '$379.99 ',
#        '$37.99 ', '$18.99 ', '$389.99 ', '$19.90 ', '$8.49 ', '$1.75 ',
#        '$14.00 ', '$4.85 ', '$46.99 ', '$109.99 ', '$154.99 ', '$3.08 ',
#        '$2.59 ', '$4.80 ', '$1.96 ', '$19.40 ', '$3.90 ', '$4.59 ',
#        '$15.46 ', '$3.04 ', '$4.29 ', '$2.60 ', '$3.28 ', '$4.60 ',
# ...

# %%
items_to_remove=['+',',','$']
cols_to_clean=['installs','price']
for item in items_to_remove:
    for col in cols_to_clean:
        apps[col]=apps[col].str.replace(item,'')
apps.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   reviews  size  installs  type price content rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       genres last updated         current ver   android ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
apps.installs.unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
apps['price'].unique()
# Out:
# array(['0', '4.99 ', '3.99 ', '6.99 ', '1.49 ', '2.99 ', '7.99 ', '5.99 ',
#        '3.49 ', '1.99 ', '9.99 ', '7.49 ', '0.99 ', '9.00 ', '5.49 ',
#        '10.00 ', '24.99 ', '11.99 ', '79.99 ', '16.99 ', '14.99 ',
#        '1.00 ', '29.99 ', '12.99 ', '2.49 ', '10.99 ', '1.50 ', '19.99 ',
#        '15.99 ', '33.99 ', '74.99 ', '39.99 ', '3.95 ', '4.49 ', '1.70 ',
#        '8.99 ', '2.00 ', '3.88 ', '25.99 ', '399.99 ', '17.99 ',
#        '400.00 ', '3.02 ', '1.76 ', '4.84 ', '4.77 ', '1.61 ', '2.50 ',
#        '1.59 ', '6.49 ', '1.29 ', '5.00 ', '13.99 ', '299.99 ', '379.99 ',
#        '37.99 ', '18.99 ', '389.99 ', '19.90 ', '8.49 ', '1.75 ',
#        '14.00 ', '4.85 ', '46.99 ', '109.99 ', '154.99 ', '3.08 ',
#        '2.59 ', '4.80 ', '1.96 ', '19.40 ', '3.90 ', '4.59 ', '15.46 ',
#        '3.04 ', '4.29 ', '2.60 ', '3.28 ', '4.60 ', '28.99 ', '2.95 ',
#        '2.90 ', '1.97 ', '200.00 ', '89.99 ', '2.56 ', '30.99 ', '3.61 ',
# ...

# %%
apps[apps['price']=='Everyone']
# Out:
#                                            app category  rating reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          size installs type     price content rating     genres last updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       current ver android ver
# 10472  4.0 and up         NaN

# %%
apps.drop(10472,inplace=True)
apps[apps['price']=='Everyone']
# Out:
# Empty DataFrame
# Columns: [app, category, rating, reviews, size, installs, type, price, content rating, genres, last updated, current ver, android ver]
# Index: []

# %%
apps['installs']=apps['installs'].astype('int')
apps['price']=apps['price'].astype('float')
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10357 non-null  object
#  1   category        10357 non-null  object
#  2   rating          8892 non-null   float64
#  3   reviews         10357 non-null  object
#  4   size            10357 non-null  object
#  5   installs        10357 non-null  int32
#  6   type            10356 non-null  object
#  7   price           10357 non-null  float64
#  8   content rating  10357 non-null  object
#  9   genres          10357 non-null  object
#  10  last updated    10357 non-null  object
#  11  current ver     10349 non-null  object
#  12  android ver     10355 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Change Reviews type

# %%
apps['reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
apps['reviews']=apps['reviews'].astype('int')

# %%
apps['reviews'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Change Last update into a datetime column

# %%
apps['last updated'] = pd.to_datetime(apps['last updated'])
apps['last updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: last updated, Length: 10357, dtype: datetime64[ns]

# %% [markdown]
# ##### Extract year and month of the last update

# %%
apps['year']=pd.DatetimeIndex(apps['last updated']).year

# %%
apps['month']=pd.DatetimeIndex(apps['last updated']).month

# %%
apps.drop(columns='last updated',inplace=True)

# %%
apps.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews  size  installs  type  price content rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       genres         current ver   android ver  year  month
# 0               Art & Design               1.0.0  4.0.3 and up  2018      1
# ...

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10357 non-null  object
#  1   category        10357 non-null  object
#  2   rating          8892 non-null   float64
#  3   reviews         10357 non-null  int32
#  4   size            10357 non-null  object
#  5   installs        10357 non-null  int32
#  6   type            10356 non-null  object
#  7   price           10357 non-null  float64
#  8   content rating  10357 non-null  object
#  9   genres          10357 non-null  object
#  10  current ver     10349 non-null  object
#  11  android ver     10355 non-null  object
#  12  year            10357 non-null  int64
#  13  month           10357 non-null  int64
# dtypes: float64(2), int32(2), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Cleaning Size column

# %%
apps['size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# ###### Remove all characters from size and convert it to float

# %%
apps['size']=apps['size'].str.replace('M','000')
apps['size']=apps['size'].str.replace('k','')
apps['size']=apps['size'].replace("Varies with device",np.nan)
apps['size']=apps['size'].astype('float')

# %%
apps.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews     size  installs  type  price content rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       genres         current ver   android ver  year  month
# 0               Art & Design               1.0.0  4.0.3 and up  2018      1
# ...

# %% [markdown]
# There is a problem!! There are some applications size in megabyte and some in kilobyte

# %% [markdown]
# ###### Convert mega to kilo then convert all to mega

# %%
for i in apps['size']:
    if float(i) < 10:
        apps['size']=apps['size'].replace(i,i*1000)
apps.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews     size  installs  type  price content rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       genres         current ver   android ver  year  month
# 0               Art & Design               1.0.0  4.0.3 and up  2018      1
# ...

# %%
apps['size']=apps['size']/1000

# %%
apps['size']
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: size, Length: 10357, dtype: float64

# %%
apps.describe()
# Out:
#             rating       reviews         size      installs         price  \
# count  8892.000000  1.035700e+04  8831.000000  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05    21.277437  1.415776e+07      1.030800
# std       0.522377  2.696778e+06    22.547690  8.023955e+07     16.278625
# min       1.000000  0.000000e+00     0.010000  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01     4.700000  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04    29.000000  1.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000
#
#                year         month
# count  10357.000000  10357.000000
# mean    2017.382929      6.397026
# std        1.112766      2.606359
# min     2010.000000      1.000000
# 25%     2017.000000      5.000000
# 50%     2018.000000      7.000000
# 75%     2018.000000      8.000000
# ...

# %% [markdown]
# ## Dealing with null values

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10357 non-null  object
#  1   category        10357 non-null  object
#  2   rating          8892 non-null   float64
#  3   reviews         10357 non-null  int32
#  4   size            8831 non-null   float64
#  5   installs        10357 non-null  int32
#  6   type            10356 non-null  object
#  7   price           10357 non-null  float64
#  8   content rating  10357 non-null  object
#  9   genres          10357 non-null  object
#  10  current ver     10349 non-null  object
#  11  android ver     10355 non-null  object
#  12  year            10357 non-null  int64
#  13  month           10357 non-null  int64
# dtypes: float64(3), int32(2), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
null_values=pd.DataFrame({"Number":apps.isnull().sum().sort_values(ascending=False)})
null_values["Percentage"]=null_values['Number']/len(apps)*100

# %%
null_values
# Out:
#                 Number  Percentage
# size              1526   14.733996
# rating            1465   14.145023
# current ver          8    0.077242
# android ver          2    0.019311
# type                 1    0.009655
# app                  0    0.000000
# category             0    0.000000
# reviews              0    0.000000
# installs             0    0.000000
# price                0    0.000000
# content rating       0    0.000000
# genres               0    0.000000
# year                 0    0.000000
# month                0    0.000000

# %%
null_counts = apps.isna().sum().sort_values(ascending=False)/len(apps)
plt.figure(figsize=(16,8))
plt.xticks(np.arange(len(null_counts)),null_counts.index,rotation='vertical')
plt.ylabel('fraction of rows with missing data')
plt.bar(np.arange(len(null_counts)),null_counts)
plt.ylim(0,0.17)
plt.savefig('null.png')

# %% [markdown]
# I will replace null vals with random values, why? Easily because that's the best way to keep the distribution of the data.

# %% [markdown]
# ###### Let's see the distribution of the rating before imputing

# %%
apps['size'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Imputing

# %%
### lets create a function so that I can easily do it for all features
def Random_value_imputation(feature):
    random_sample=apps[feature].dropna().sample(apps[feature].isnull().sum())               
    random_sample.index=apps[apps[feature].isnull()].index
    apps.loc[apps[feature].isnull(),feature]=random_sample

# %%
for col in apps:
    Random_value_imputation(col)

# %%
null_values=pd.DataFrame({"Number":apps.isnull().sum().sort_values(ascending=False)})
null_values["Percentage"]=null_values['Number']/len(apps)*100
null_values
# Out:
#                 Number  Percentage
# app                  0         0.0
# category             0         0.0
# rating               0         0.0
# reviews              0         0.0
# size                 0         0.0
# installs             0         0.0
# type                 0         0.0
# price                0         0.0
# content rating       0         0.0
# genres               0         0.0
# current ver          0         0.0
# android ver          0         0.0
# year                 0         0.0
# month                0         0.0

# %% [markdown]
# ###### Let's look again on the size distribution after imputation

# %%
apps['size'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we said before that's the best way to maintain the distribution of the data.

# %%
apps.describe()
# Out:
#              rating       reviews          size      installs         price  \
# count  10357.000000  1.035700e+04  10357.000000  1.035700e+04  10357.000000
# mean       4.185256  4.059046e+05     21.103856  1.415776e+07      1.030800
# std        0.525322  2.696778e+06     22.445766  8.023955e+07     16.278625
# min        1.000000  0.000000e+00      0.010000  0.000000e+00      0.000000
# 25%        4.000000  3.200000e+01      4.700000  1.000000e+03      0.000000
# 50%        4.300000  1.680000e+03     13.000000  1.000000e+05      0.000000
# 75%        4.500000  4.641600e+04     29.000000  1.000000e+06      0.000000
# max        5.000000  7.815831e+07    100.000000  1.000000e+09    400.000000
#
#                year         month
# count  10357.000000  10357.000000
# mean    2017.382929      6.397026
# std        1.112766      2.606359
# min     2010.000000      1.000000
# 25%     2017.000000      5.000000
# 50%     2018.000000      7.000000
# 75%     2018.000000      8.000000
# ...

# %% [markdown]
# #### Extract Numerical & Categorical Features

# %%
num_features=[col for col in apps.columns if apps[col].dtype!='O']
num_data = apps[num_features]
num_data.head()
# Out:
#    rating  reviews  size  installs  price  year  month
# 0     4.1      159  19.0     10000    0.0  2018      1
# 1     3.9      967  14.0    500000    0.0  2018      1
# 2     4.7    87510   8.7   5000000    0.0  2018      8
# 3     4.5   215644  25.0  50000000    0.0  2018      6
# 4     4.3      967   2.8    100000    0.0  2018      6

# %%
cat_features=[col for col in apps.columns if apps[col].dtype=='O']
cat_data = apps[cat_features]
cat_data.head()
# Out:
#                                                  app        category  type  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  Free
# 1                                Coloring book moana  ART_AND_DESIGN  Free
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  Free
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN  Free
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  Free
#
#   content rating                     genres         current ver   android ver
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# 1       Everyone  Art & Design;Pretend Play               2.0.0  4.0.3 and up
# 2       Everyone               Art & Design               1.2.4  4.0.3 and up
# 3           Teen               Art & Design  Varies with device    4.2 and up
# 4       Everyone    Art & Design;Creativity                 1.1    4.4 and up

# %% [markdown]
# ## Check outliers

# %%
def outlier_thresholds(dataframe, variable):
    quartile1 = dataframe[variable].quantile(0.10)
    quartile3 = dataframe[variable].quantile(0.90)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
def has_outliers(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    if dataframe[(dataframe[variable] < low_limit) | (dataframe[variable] > up_limit)].any(axis=None):
        print(variable, "yes")
    else :
        print(variable, "no")

# %%
for col in num_data.columns:
    has_outliers(num_data, col)
# Out:
# rating yes
# reviews yes
# size no
# installs yes
# price yes
# year yes
# month no

# %%
plt.figure(figsize=(25,10))
for i,col in enumerate(num_data.columns):
    plt.subplot(3,5,i+1)
    sns.boxplot(num_data[col])

# %%
## function to get ride of qutliers
def replace_with_thresholds(dataframe, numeric_columns):
    for variable in numeric_columns:
        low_limit, up_limit = outlier_thresholds(dataframe, variable)
        dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
        dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
replace_with_thresholds(num_data, num_data.columns)

# %%
for col in num_data.columns:
    has_outliers(num_data, col)
# Out:
# rating no
# reviews no
# size no
# installs no
# price no
# year no
# month no

# %%
plt.figure(figsize=(22,18))
for i,col in enumerate(num_data.columns):
    plt.subplot(4,9,i+1)
    sns.boxplot(num_data[col])

# %% [markdown]
# ## Explaratory Data Analysis

# %%
apps.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews  size  installs  type  price content rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       genres         current ver   android ver  year  month
# 0               Art & Design               1.0.0  4.0.3 and up  2018      1
# ...

# %% [markdown]
# ##### Most popular categories

# %%
apps['category'].value_counts()
# Out:
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
#Visualize it
plt.figure(figsize=(15,10))
sns.countplot(apps['category'],order=apps['category'].value_counts().index)
plt.xticks(rotation=90);

# %% [markdown]
# We see here that the "Family" and "Gaming" apps are the most vairal categories on Google play store

# %% [markdown]
# ##### Most installed categories

# %%
category_installs=apps.groupby('category')['installs'].mean().sort_values(ascending=False)
category_installs
# Out:
# category
# COMMUNICATION          6.598983e+07
# SOCIAL                 4.469239e+07
# VIDEO_PLAYERS          3.555430e+07
# PRODUCTIVITY           3.062185e+07
# PHOTOGRAPHY            3.019021e+07
# GAME                   2.813918e+07
# TRAVEL_AND_LOCAL       2.684341e+07
# ENTERTAINMENT          2.212306e+07
# NEWS_AND_MAGAZINES     2.042886e+07
# TOOLS                  1.358573e+07
# SHOPPING               1.148816e+07
# BOOKS_AND_REFERENCE    8.332476e+06
# PERSONALIZATION        5.346636e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# WEATHER                5.196348e+06
# FAMILY                 5.168138e+06
# HEALTH_AND_FITNESS     4.447786e+06
# SPORTS                 4.354913e+06
# EDUCATION              4.107323e+06
# FINANCE                2.139858e+06
# FOOD_AND_DRINK         2.079829e+06
# BUSINESS               2.022634e+06
# ART_AND_DESIGN         1.912894e+06
# HOUSE_AND_HOME         1.565156e+06
# LIFESTYLE              1.433843e+06
# DATING                 1.053756e+06
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(category_installs.index,category_installs)
plt.xticks(rotation=90);

# %% [markdown]
# As we see in this plot "Communication" and "Social" apps cetegories are the most installed, That's normal our lives right now are depending on these apps and we deal with it daily.

# %% [markdown]
# #### Highest rated categories

# %%
cat_ratings=apps.groupby('category')['rating'].mean().sort_values(ascending=False)
cat_ratings.head()
# Out:
# category
# EVENTS             4.389062
# EDUCATION          4.370000
# ART_AND_DESIGN     4.355385
# PERSONALIZATION    4.281701
# GAME               4.276806
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.barplot(cat_ratings.index,cat_ratings)
plt.xticks(rotation=90);

# %% [markdown]
# From this plot we can sae that all ratings are close, So I think the category not affects the rating of the app.

# %% [markdown]
# ### Does size affect installs

# %%
plt.figure(figsize=(15,10))
plt.scatter(x=num_data['size'],y=num_data['installs'])
plt.xlabel('Size')
plt.ylabel('Installs')
plt.title('Size Vs. Installs');

# %% [markdown]
# Apps with size of 1 to 10 Mb are most likely to be installed, Also the apps with large size have alot of installs but the apps with small sizes are the most.

# %% [markdown]
# ###### Categories average sizes

# %%
category_size=apps.groupby('category')['size'].mean().sort_values()
category_size
# Out:
# category
# TOOLS                  10.129327
# LIBRARIES_AND_DEMO     11.505047
# PERSONALIZATION        11.923907
# ART_AND_DESIGN         12.800000
# BOOKS_AND_REFERENCE    13.775922
# WEATHER                14.021939
# BEAUTY                 14.045283
# COMICS                 14.055883
# NEWS_AND_MAGAZINES     14.221860
# PRODUCTIVITY           14.329283
# BUSINESS               14.458838
# EVENTS                 14.820844
# COMMUNICATION          14.899014
# LIFESTYLE              15.270542
# HOUSE_AND_HOME         15.495112
# SHOPPING               15.877335
# VIDEO_PLAYERS          16.937417
# DATING                 17.041454
# SOCIAL                 17.270189
# MAPS_AND_NAVIGATION    17.416226
# FINANCE                18.277503
# PHOTOGRAPHY            18.529720
# EDUCATION              18.649862
# MEDICAL                19.368441
# HEALTH_AND_FITNESS     20.391614
# AUTO_AND_VEHICLES      20.518659
# FOOD_AND_DRINK         21.514516
# PARENTING              22.461667
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(category_size.index,category_size)
plt.xticks(rotation=90);

# %% [markdown]
# ### Relationship between rating and installs

# %%
plt.figure(figsize=(15,12))
sns.scatterplot(x='installs',y='rating',data=apps);

# %% [markdown]
# Apps with high number of installs tend to have higher ratings.

# %% [markdown]
# ### Free vs. Paid apps

# %%
plt.figure(figsize=(9,6))
sns.countplot(apps['type']);

# %% [markdown]
# Free apps are much more viral in Google Play Store than Paid apps

# %% [markdown]
# #### Does type of the apps affect number of installs

# %%
type_installs=apps.groupby('type')['installs'].mean().sort_values(ascending=False)
type_installs.head()
# Out:
# type
# Free    1.527968e+07
# Paid    9.049135e+04
# Name: installs, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.barplot(type_installs.index,type_installs)
plt.xticks(rotation=90)
plt.ylim(0,800000)
plt.xlabel("App type")
plt.ylabel('Average Installs');

# %% [markdown]
# People tend to install Free apps much more than install Paid apps

# %% [markdown]
# #### App rating according to its type

# %%
type_rating=apps.groupby('type')['rating'].mean()
type_rating
# Out:
# type
# Free    4.180505
# Paid    4.244837
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(9,6))
sns.boxplot(y=apps['rating'],x=apps['type']);

# %% [markdown]
# Average rating of paid apps relatively higher than the free apps

# %% [markdown]
# #### Explore more about paid apps

# %%
paid_apps=apps[apps['type']== 'Paid']

# %%
#Split paid apps into categories according to their prices
bins = [0,50,150,250,350, np.inf]
names = ['0.99-50', '51-150','151-250','251-350', '350-']

paid_apps['price_range'] = pd.cut(paid_apps['price'], bins, labels=names)
apps['price_range'] = pd.cut(apps['price'], bins, labels=names)

# %%
price_installs=paid_apps.groupby('price_range')['installs'].mean()
price_installs
sns.barplot(price_installs.index,price_installs)
plt.ylabel('average installs');

# %% [markdown]
# Cheap price apps have more installs than the expensive ones.

# %%
price_rat=apps.groupby('price_range')['rating'].mean()
plt.bar(price_rat.index,price_rat)
plt.show()
price_rat
# Out:
# price_range
# 0.99-50    4.257008
# 51-150     3.975000
# 151-250    3.950000
# 251-350    3.800000
# 350-       3.812500
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(15,12))
sns.scatterplot(x='price',y='installs',data=paid_apps)
plt.savefig('price_installs.png')

# %% [markdown]
# #### Content rating and Installs

# %%
con_rat_ins=apps.groupby('content rating')['installs'].mean().sort_values()
con_rat_ins
# Out:
# content rating
# Unrated            2.525000e+04
# Adults only 18+    6.666667e+05
# Mature 17+         9.598874e+06
# Everyone           1.195772e+07
# Teen               2.697930e+07
# Everyone 10+       2.968507e+07
# Name: installs, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.barplot(con_rat_ins.index,con_rat_ins)
# Out:
# <AxesSubplot:xlabel='content rating', ylabel='installs'>

# %%
plt.figure(figsize=(12,8))
content_ratings = sns.violinplot(x="content rating",y="rating",data=apps, kind="box", height = 10 ,palette = "Set3")
content_ratings.set_xlabel(xlabel = 'Content Rating', fontsize = 9)
content_ratings.set_ylabel(ylabel = 'Rating', fontsize = 9)
content_ratings.set_title(label = 'Rating vs Content Rating');

# %% [markdown]
# The top 3 content rating categories Teenage is a common factor between them, the teenagers arethe most sector using google play app store.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(apps['rating'],apps['reviews']);

# %% [markdown]
# The reviews increse as the naumber of rating increase.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='reviews',data=apps)
plt.savefig('price_reviews.png')

# %% [markdown]
# Reviews are high in free and cheap apps

# %% [markdown]
# #### Most freq year in apps updates

# %%
plt.figure(figsize=(12,8))
freq= pd.Series()
freq=apps['year'].value_counts()
freq.plot()
plt.xlabel("year")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %% [markdown]
# Developers knew lately that they need to update their apps from time to time to attract more people.

# %%
plt.figure(figsize=(12,8))
sns.barplot(apps['year'],apps['installs'],ci=0);

# %% [markdown]
# Apps which last update was in 2018 have the highest installes

# %% [markdown]
# ## Modeling

# %% [markdown]
# #### Data preprocessing

# %%
X=apps.drop(columns=['app','price_range','rating'])
y=np.array(apps.iloc[:,2])

# %%
X.head()
# Out:
#          category  reviews  size  installs  type  price content rating  \
# 0  ART_AND_DESIGN      159  19.0     10000  Free    0.0       Everyone
# 1  ART_AND_DESIGN      967  14.0    500000  Free    0.0       Everyone
# 2  ART_AND_DESIGN    87510   8.7   5000000  Free    0.0       Everyone
# 3  ART_AND_DESIGN   215644  25.0  50000000  Free    0.0           Teen
# 4  ART_AND_DESIGN      967   2.8    100000  Free    0.0       Everyone
#
#                       genres         current ver   android ver  year  month
# 0               Art & Design               1.0.0  4.0.3 and up  2018      1
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up  2018      1
# 2               Art & Design               1.2.4  4.0.3 and up  2018      8
# 3               Art & Design  Varies with device    4.2 and up  2018      6
# 4    Art & Design;Creativity                 1.1    4.4 and up  2018      6

# %%
y
# Out:
# array([4.1, 3.9, 4.7, ..., 3.4, 4.5, 4.5])

# %%
from sklearn.preprocessing import LabelEncoder
features_categorical=X.select_dtypes(include=['object']).columns.tolist()
encoder=LabelEncoder()

# %%
X['category']=encoder.fit_transform(X['category'])
X['type']=encoder.fit_transform(X['type'])
X['content rating']=encoder.fit_transform(X['content rating'])
X['genres']=encoder.fit_transform(X['genres'])
X['current ver']=encoder.fit_transform(X['current ver'])
X['android ver']=encoder.fit_transform(X['android ver'])

# %%
X
# Out:
#        category  reviews   size  installs  type  price  content rating  \
# 0             0      159  19.00     10000     0    0.0               1
# 1             0      967  14.00    500000     0    0.0               1
# 2             0    87510   8.70   5000000     0    0.0               1
# 3             0   215644  25.00  50000000     0    0.0               4
# 4             0      967   2.80    100000     0    0.0               1
# ...         ...      ...    ...       ...   ...    ...             ...
# 10836        11       38  53.00      5000     0    0.0               1
# 10837        11        4   3.60       100     0    0.0               1
# 10838        20        3   9.50      1000     0    0.0               1
# 10839         3      114   0.01      1000     0    0.0               3
# 10840        18   398307  19.00  10000000     0    0.0               1
#
#        genres  current ver  android ver  year  month
# 0           9          114           15  2018      1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(copy=True, feature_range=(0, 1))
X[['reviews','size','installs']] = scaler.fit_transform(X[['reviews','size','installs']])

# %%
X.head()
# Out:
#    category   reviews      size  installs  type  price  content rating  \
# 0         0  0.000002  0.189919   0.00001     0    0.0               1
# 1         0  0.000012  0.139914   0.00050     0    0.0               1
# 2         0  0.001120  0.086909   0.00500     0    0.0               1
# 3         0  0.002759  0.249925   0.05000     0    0.0               4
# 4         0  0.000012  0.027903   0.00010     0    0.0               1
#
#    genres  current ver  android ver  year  month
# 0       9          114           15  2018      1
# 1      12          996           15  2018      1
# 2       9          458           15  2018      8
# 3       9         2716           18  2018      6
# 4      11          272           20  2018      6

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=44)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_jobs=-1)
estimators = np.arange(10, 100, 10)
scores = []
for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))
plt.figure(figsize=(7, 5))
plt.title("Effect of Estimators")
plt.xlabel("no. estimator")
plt.ylabel("score")
plt.plot(estimators, scores)
results = list(zip(estimators,scores))

# %%
model = RandomForestRegressor(n_estimators=70)
# Fit on training data
model.fit(X_train, y_train)
# Actual class predictions
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.2517820584084663
# 0.3408257212647682

# %% [markdown]
# ### Conclusions and Recommendations

# %% [markdown]
# <b> Communications </b> and <b> Social</b> are the most installed categories <br>
# People tend to install <b> Free </b> apps than <b> Paid </b> ones <br>
# In paid apps, People tend to install <b> Cheap </b> apps than <b> Expensive </b> ones <br>
# Developers have to know that the more updated they apps are the more they get more installs.<br>

# %% [markdown]
# Developers and Tech companies have to focus more on categories like Communication, Social, Video palyers, and gaming apps, These categories apps numbers are little according to all google play store apps, although they get high ratings and have high installs, But developers have to know more about what people needs in there apps and to be easy in use and get their satisfaction.
